# %%
import DB as db
import ipywidgets as widgets
from IPython.display import display


query_add_url = '''
insert into fgroups (
lang,
sug_kvutza,
url,
branch,
group_title,
description,
ezor,
status_kvuza
)
values(
{lang},
{url},
{branch},
{group_title},
{description},
{ezor},
{status_kvuza}
)
'''

def add_url(lang, sug_kvutza, url, branch, group_title, description, ezor, status_kvuza): 
    
    query = str(f''' 
        insert into fbgroups (
        lang,
        sug_kvutza,
        url,
        branch,
        group_title,
        description,
        ezor
        )
        values(
        '{lang}',
        '{sug_kvutza}',
        '{url}',
        '{branch}',
        '{group_title}',
        '{description}',
        '{ezor}'
        )''')
    
    db.execute(query, do='insert')

def get_dublicates():
    query = 'SELECT * FROM `fbgroups` WHERE `url` IN (SELECT `url` FROM `fbgroups` GROUP BY `url` HAVING COUNT(*) > 1) ORDER BY `url`'
    df = db.execute(query , do='select')
    print(df)
 
def delete_ROWID(ROWID):
    query = str(f'DELETE FROM `fbgroups` where ROWID =  {ROWID}')
    print(query)
    db.execute(query , do='delete')
    get_dublicates()
    
def render_inputs():
    '''
    виджеты 
    '''
    lang = widgets.RadioButtons(
    options=['he', 'ru'],
    #    value='pineapple', # Defaults to 'pineapple'
    #    layout={'width': 'max-content'}, # If the items' names are long
    description='Lang',
    disabled=False
    )

    display(lang)

    ''' ------------------------------------------------------ '''
    sug_kvutza = widgets.RadioButtons(
    options=['pirsum', 'mexirot'],
    #    value='pineapple', # Defaults to 'pineapple'
    #    layout={'width': 'max-content'}, # If the items' names are long
    description='sug_kvutza',
    disabled=False
    )

    display(sug_kvutza)
    ''' ------------------------------------------------------ '''
    url = widgets.Text(
        value='',
        placeholder='',
        description='URL' ,
        disabled=False   
    )
    display(url)
    ''' ------------------------------------------------------ '''
    branch = widgets.RadioButtons(
    options=['aluf', 'tzama'],
    #    value='pineapple', # Defaults to 'pineapple'
    #    layout={'width': 'max-content'}, # If the items' names are long
    description='sug_kvutza',
    disabled=False
    )
    display(branch)
    ''' ------------------------------------------------------ '''
    group_title = widgets.Text(
        value='',
        placeholder='',
        description='group_title' ,
        disabled=False   
    )
    display(group_title)
    ''' ------------------------------------------------------ '''
    description = widgets.Text(
        value='',
        placeholder='',
        description='description' ,
        disabled=False   
    )
    display(description)
    ''' ------------------------------------------------------ '''
    ezor = widgets.RadioButtons(
        options=['Рамла', 'Ришон лецион' , 'Реховот', 'Несциона','Явне','כפר-סבא>הוד-השרון>רעננה' , 'רעננה, הרצליה, רמת השרון',
                 'Тель Авив','Рамат Ган','Центр' , 'Израиль' , 'Нетания','Юг', ' Тель авив',
                'Холон','Петах Тиква'],
        #    value='pineapple', # Defaults to 'pineapple'
        #    layout={'width': 'max-content'}, # If the items' names are long
        description='',
        disabled=False
    )
    display(ezor)
    ''' ------------------------------------------------------ '''
    status_kvuza = widgets.RadioButtons(
        options=['active'],
        #    value='pineapple', # Defaults to 'pineapple'
        #    layout={'width': 'max-content'}, # If the items' names are long
        description='',
        disabled=False
    )
    display(status_kvuza)
    ''' ------------------------------------------------------ '''


    def on_button_save_clicked(b): # Описываем обработчик события
        add_url(lang.value, url.value, sug_kvutza.value, branch.value, group_title.value, description.value, ezor.value, status_kvuza.value)
        url.value = ''
        get_dublicates()

    button_save = widgets.Button(description="Save")
    button_save.on_click(on_button_save_clicked) # Назначаем этот обработчик на событие "on_click"
    display(button_save)

render_inputs()

get_dublicates()

textbox_ROWID = widgets.Text(
        value='',
        placeholder='',
        description='ROWID' ,
        disabled=False   
    )
display(textbox_ROWID)
    
def button_delete_ROWID_clicked(b): # Описываем обработчик события
    delete_ROWID(textbox_ROWID.value)
    get_dublicates()

button_delete_ROWID = widgets.Button(description="DELETE")
button_delete_ROWID.on_click(button_delete_ROWID_clicked) # Назначаем этот обработчик на событие "on_click"
display(button_delete_ROWID)
# Out:
# RadioButtons(description='Lang', options=('he', 'ru'), value='he')
# RadioButtons(description='sug_kvutza', options=('pirsum', 'mexirot'), value='pirsum')
# Text(value='', description='URL', placeholder='')
# RadioButtons(description='sug_kvutza', options=('aluf', 'tzama'), value='aluf')
# Text(value='', description='group_title', placeholder='')
# Text(value='', description='description', placeholder='')
# RadioButtons(options=('Рамла', 'Ришон лецион', 'Реховот', 'Несциона', 'כפר-סבא>הוד-השרון>רעננה', 'רעננה, הרצלי…
# RadioButtons(options=('active',), value='active')
# Button(description='Save', style=ButtonStyle())
#     ROWID lang                                         sug_kvutza branch  \
# 0     303   he   https://www.facebook.com/groups/783257451734839/   aluf
# 1     304   he  https://www.facebook.com/groups/1695514337336393/   aluf
# 2     305   he   https://www.facebook.com/groups/682477508874253/   aluf
# 3     306   he  https://www.facebook.com/groups/1667836613432760/   aluf
# 4     307   he   https://www.facebook.com/groups/832109660500543/   aluf
# 5     308   he  https://www.facebook.com/groups/1483458418543831/   aluf
# 6     309   he   https://www.facebook.com/groups/832109660500543/   aluf
# 7     310   he   https://www.facebook.com/groups/730637451192951/   aluf
# 8     311   he   https://www.facebook.com/groups/273444050154264/   aluf
# 9     312   he  https://www.facebook.com/groups/2009438805769518/   aluf
# 10    313   ru       https://www.facebook.com/groups/israelboard/   aluf
# 11    314   ru  https://www.facebook.com/groups/1957095007710546/   aluf
# 12    315   ru  https://www.facebook.com/groups/1695514337336393/   aluf
# 13    316   ru    https://www.facebook.com/groups/592786411148795   aluf
# 14    317   ru  https://www.facebook.com/groups/woda.obyavleni...   aluf
# 15    318   he  https://www.facebook.com/groups/1744646929157519/   aluf
# 16    319   he  https://www.facebook.com/groups/79914171347047...   aluf
# 17    320   he  https://www.facebook.com/groups/shehunat.hatikva/   aluf
# 18    321   he        https://www.facebook.com/groups/doronkrief/   aluf
# 19    322   he  https://www.facebook.com/groups/1988764218090482/   aluf
# 20    323   he   https://www.facebook.com/groups/832109660500543/   aluf
# 21    324   he   https://www.facebook.com/groups/839147156267947/   aluf
# 22    325   ru  https://www.facebook.com/groups/RishonLeZionIs...   aluf
# 23    326   ru   https://www.facebook.com/groups/293855971167565/   aluf
# 24    327   ru  https://www.facebook.com/groups/21241099912808...   aluf
# 25    328   ru  https://www.facebook.com/groups/1042412669171412/   aluf
# 26    329   ru  https://www.facebook.com/groups/10424126691714...   aluf
# 27    330   ru   https://www.facebook.com/groups/776769506064343/   aluf
# 28    331   ru   https://www.facebook.com/groups/212410999128080/   aluf
# 29    332   ru   https://www.facebook.com/groups/539932246694641/   aluf
# 30    333   ru  https://www.facebook.com/groups/2530024397218329/   aluf
# 31    334   ru   https://www.facebook.com/groups/298703436983060/   aluf
# 32    336   he  https://www.facebook.com/groups/11BusinessAdve...   aluf
# 33    337   he  https://www.facebook.com/groups/57562904931174...   aluf
# 34    338   he   https://www.facebook.com/groups/272843590109888/   aluf
# 35    339   he  https://www.facebook.com/groups/83914715626794...   aluf
# 36    340   ru           https://www.facebook.com/groups/doskail/   aluf
# 37    341   ru    https://www.facebook.com/groups/512082108878356   aluf
# 38    342   ru  https://www.facebook.com/groups/68122108197668...   aluf
# 39    343   ru  https://www.facebook.com/groups/56802212989859...   aluf
# 40    344   ru           https://www.facebook.com/promaster.co.il   aluf
# 41    345   ru   https://www.facebook.com/groups/180537799074400/   aluf
# 42    346   ru   https://www.facebook.com/groups/180537799074400/   aluf
# 43    347   ru   https://www.facebook.com/groups/512082108878356/   aluf
# 44    348   ru           https://www.facebook.com/promaster.co.il   aluf
# 45    349   ru  https://www.facebook.com/groups/doskail/buy_se...   aluf
# 46    350   he  https://www.facebook.com/groups/1168933626609608/   aluf
# 47    351   he     https://www.facebook.com/groups/ramatgangroup/   aluf
# 48    352   he    https://www.facebook.com/groups/727595817771396   aluf
#
#        url                                        group_title  \
# 0   pirsum                          פואבלו אספניול - נווה חוף
# 1   pirsum                            פורום תושבי שיכון המזרח
# 2   pirsum                           פורום ראשון למען התושבים
# 3   pirsum                        פורום שכונות כפר גנים א-ב-ג
# 4   pirsum                       פורום התושבים של ראשון לציון
# 5   pirsum               יהוד -מונסון שלנו לפרסום עסקים חופשי
# 6   pirsum               יהוד -מונסון שלנו לפרסום עסקים חופשי
# 7   pirsum  למכירה ברחובות Общедоступная группа  · Участни...
# 8   pirsum                        פורום בת ים המקורי מאיר בכר
# 9   pirsum                               פורום רחובות והסביבה
# 10  pirsum                           Доска объявлений Израиля
# 11  pirsum                                        ראשון לציון
# 12  pirsum                            פורום תושבי שיכון המזרח
# 13  pirsum                          פורום נס ציונה העיר והבית
# 14  pirsum                    woda.co.il - ОБЪЯВЛЕНИЯ ИЗРАИЛЯ
# 15  pirsum                                         פרסום חינם
# 16  pirsum      ראשל"צנט - עסקים ראשון לציון והסביבה באינטרנט
# 17  pirsum  פורום שכונת התקווה והסביבה פרסומים חינם מהאזור...
# 18  pirsum                                             פירסום
# 19  pirsum                פרסום חינם בכל תחום (לפרגן בלייקים)
# 20  pirsum                       פורום התושבים של ראשון לציון
# 21  pirsum                               לוח עסקים - רחובות !
# 22  pirsum      Ришон ле цион | Купи | Продай | Сними | Отдай
# 23  pirsum                                         מוכרים הכל
# 24  pirsum                  לוח מודעות - בת ים חולון ראשל"צ ♡
# 25  pirsum                     לוח מכירה / קניה הגדול בישראל!
# 26  pirsum                     לוח מכירה / קניה הגדול בישראל!
# 27  pirsum        רעננה, הרצליה, רמת השרון - פרסום חופשי ❤️🇮🇱
# 28  pirsum                  לוח מודעות - בת ים חולון ראשל"צ ♡
# 29  pirsum                                Ремонты, ремонты...
# 30  pirsum                                  תושבי תל אביב-יפו
# 31  pirsum                                     פרסום בחינם !!
# 32  pirsum                                        פרסום עסקים
# 33  pirsum         עושים שוק במרכז והשפלה ו -יד שניה ...קח ות
# 34  pirsum                             פורום נס ציונה והסביבה
# 35  pirsum                               לוח עסקים - רחובות !
# 36  pirsum                    Доска объявлений - весь Израиль
# 37  pirsum                                  Барахолка Израиль
# 38  pirsum                                  Барахолка Израиль
# 39  pirsum                     Русскоязычный бизнес в Израиле
# 40  pirsum                                    ProMaster.co.il
# 41  pirsum   https://www.facebook.com/groups/180537799074400/
# 42  pirsum                             Обмен услугами Израиль
# 43  pirsum                                  Барахолка Израиль
# 44  pirsum
# 45  pirsum
# 46  pirsum
# 47  pirsum                            עסקים ברמת גן - גבעתיים
# 48  pirsum                       ТЕЛЬ - АВИВ ✅Утро✅День✅Вечер
#
#                                description          ezor status_kvutza
# 0                                                  Рамла          None
# 1                                           Ришон лецион          None
# 2                                           Ришон лецион          None
# 3                                           Ришон лецион          None
# 4                                           Ришон лецион          None
# 5                                           Ришон лецион          None
# 6                                           Ришон лецион          None
# 7                                           Ришон лецион          None
# 8                                           Ришон лецион          None
# 9                                                Реховот          None
# 10                                               Израиль          None
# 11                                          Ришон лецион          None
# 12                                          Ришон лецион          None
# 13                                          Ришон лецион          None
# 14                                               Израиль          None
# 15                                               Израиль          None
# 16                                          Ришон лецион          None
# 17                                          Ришон лецион          None
# 18                                               Израиль          None
# 19                                               Израиль          None
# 20                                          Ришон лецион          None
# 21                                               Реховот          None
# 22                                          Ришон лецион          None
# 23                                             Тель авив          None
# 24                                          Ришон лецион          None
# 25                                               Израиль          None
# 26                                               Израиль          None
# 27                                               Израиль          None
# 28                                          Ришон лецион          None
# 29                                               Израиль          None
# 30                                             Тель авив          None
# 31                                                 Центр          None
# 32                                               Израиль          None
# 33                                               Израиль          None
# 34                                              Несциона          None
# 35                                               Реховот          None
# 36                                               Израиль          None
# 37                                               Израиль          None
# 38                                               Израиль          None
# 39                                               Израиль          None
# 40  @promaster.co.il  · Услуги для бизнеса       Израиль          None
# 41                                               Израиль          None
# 42                                               Израиль          None
# 43                                               Израиль          None
# 44                                               Израиль          None
# 45                                               Израиль          None
# 46                                               Израиль          None
# 47                                                 Центр          None
# 48                                             Тель авив          None
# Text(value='', description='ROWID', placeholder='')
# Button(description='DELETE', style=ButtonStyle())
#     ROWID lang                                         sug_kvutza branch  \
# 0     303   he   https://www.facebook.com/groups/783257451734839/   aluf
# 1     304   he  https://www.facebook.com/groups/1695514337336393/   aluf
# 2     305   he   https://www.facebook.com/groups/682477508874253/   aluf
# 3     306   he  https://www.facebook.com/groups/1667836613432760/   aluf
# 4     307   he   https://www.facebook.com/groups/832109660500543/   aluf
# 5     308   he  https://www.facebook.com/groups/1483458418543831/   aluf
# 6     309   he   https://www.facebook.com/groups/832109660500543/   aluf
# 7     310   he   https://www.facebook.com/groups/730637451192951/   aluf
# 8     311   he   https://www.facebook.com/groups/273444050154264/   aluf
# 9     312   he  https://www.facebook.com/groups/2009438805769518/   aluf
# 10    313   ru       https://www.facebook.com/groups/israelboard/   aluf
# 11    314   ru  https://www.facebook.com/groups/1957095007710546/   aluf
# 12    315   ru  https://www.facebook.com/groups/1695514337336393/   aluf
# 13    316   ru    https://www.facebook.com/groups/592786411148795   aluf
# 14    317   ru  https://www.facebook.com/groups/woda.obyavleni...   aluf
# 15    318   he  https://www.facebook.com/groups/1744646929157519/   aluf
pirsum                  לוח מודעות - בת ים חולון ראשל"צ ♡
# 25  pirsum                     לוח מכירה / קניה הגדול בישראל!
# 26  pirsum                     לוח מכירה / קניה הגדול בישראל!
# 27  pirsum        רעננה, הרצליה, רמת השרון - פרסום חופשי ❤️🇮🇱
# 28  pirsum                  לוח מודעות - בת ים חולון ראשל"צ ♡
# 29  pirsum                                Ремонты, ремонты...
# 30  pirsum                                  תושבי תל אביב-יפו
# 31  pirsum                                     פרסום בחינם !!
# 32  pirsum                                        פרסום עסקים
# 33  pirsum         עושים שוק במרכז והשפלה ו -יד שניה ...קח ות
# 34  pirsum                             פורום נס ציונה והסביבה
# 35  pirsum                               לוח עסקים - רחובות !
# 36  pirsum                    Доска объявлений - весь Израиль
# 37  pirsum                                  Барахолка Израиль
# 38  pirsum                                  Барахолка Израиль
# 39  pirsum                     Русскоязычный бизнес в Израиле
# 40  pirsum                                    ProMaster.co.il
# 41  pirsum   https://www.facebook.com/groups/180537799074400/
# 42  pirsum                             Обмен услугами Израиль
# 43  pirsum                                  Барахолка Израиль
# 44  pirsum
# 45  pirsum
# 46  pirsum
# 47  pirsum                            עסקים ברמת גן - גבעתיים
# 48  pirsum                       ТЕЛЬ - АВИВ ✅Утро✅День✅Вечер
# 49  pirsum       פרסום עסקים ראשון,בת ים,חולון וכל אזור המרכז
#
#                                description          ezor status_kvutza
# 0                                                  Рамла          None
# 1                                           Ришон лецион          None
# 2                                           Ришон лецион          None
# 3                                           Ришон лецион          None
# 4                                           Ришон лецион          None
# 5                                           Ришон лецион          None
# 6                                           Ришон лецион          None
# 7                                           Ришон лецион          None
# 8                                           Ришон лецион          None
# 9                                                Реховот          None
# 10                                               Израиль          None
# 11                                          Ришон лецион          None
# 12                                          Ришон лецион          None
# 13                                          Ришон лецион          None
# 14                                               Израиль          None
# 15                                               Израиль          None
# 16                                          Ришон лецион          None
# 17                                          Ришон лецион          None
# 18                                               Израиль          None
# 19                                               Израиль          None
# 20                                          Ришон лецион          None
# 21                                               Реховот          None
# 22                                          Ришон лецион          None
# 23                                             Тель авив          None
# 24                                          Ришон лецион          None
# 25                                               Израиль          None
# 26                                               Израиль          None
# 27                                               Израиль          None
# 28                                          Ришон лецион          None
# 29                                               Израиль          None
# 30                                             Тель авив          None
# 31                                                 Центр          None
# 32                                               Израиль          None
# 33                                               Израиль          None
# 34                                              Несциона          None
# 35                                               Реховот          None
# 36                                               Израиль          None
# 37                                               Израиль          None
# 38                                               Израиль          None
# 39                                               Израиль          None
# 40  @promaster.co.il  · Услуги для бизнеса       Израиль          None
# 41                                               Израиль          None
# 42                                               Израиль          None
# 43                                               Израиль          None
# 44                                               Израиль          None
# 45                                               Израиль          None
# 46                                               Израиль          None
# 47                                                 Центр          None
# 48                                             Тель авив          None
# 49                                          Ришон лецион          None
#     ROWID lang                                         sug_kvutza branch  \
# 0     303   he   https://www.facebook.com/groups/783257451734839/   aluf
# 1     304   he  https://www.facebook.com/groups/1695514337336393/   aluf
# 2     305   he   https://www.facebook.com/groups/682477508874253/   aluf
pirsum               יהוד -מונסון שלנו לפרסום עסקים חופשי
# 6   pirsum               יהוד -מונסון שלנו לפרסום עסקים חופשי
# 7   pirsum  למכירה ברחובות Общедоступная группа  · Участни...
# 8   pirsum                        פורום בת ים המקורי מאיר בכר
# 9   pirsum                               פורום רחובות והסביבה
# 10  pirsum                           Доска объявлений Израиля
# 11  pirsum                                        ראשון לציון
# 12  pirsum                            פורום תושבי שיכון המזרח
# 13  pirsum                          פורום נס ציונה העיר והבית
# 14  pirsum                    woda.co.il - ОБЪЯВЛЕНИЯ ИЗРАИЛЯ
# 15  pirsum                                         פרסום חינם
# 16  pirsum      ראשל"צנט - עסקים ראשון לציון והסביבה באינטרנט
# 17  pirsum  פורום שכונת התקווה והסביבה פרסומים חינם מהאזור...
# 18  pirsum                                             פירסום
# 19  pirsum                פרסום חינם בכל תחום (לפרגן בלייקים)
# 20  pirsum                       פורום התושבים של ראשון לציון
# 21  pirsum                               לוח עסקים - רחובות !
# 22  pirsum      Ришон ле цион | Купи | Продай | Сними | Отдай
# 23  pirsum                                         מוכרים הכל
# 24  pirsum                  לוח מודעות - בת ים חולון ראשל"צ ♡
# 25  pirsum                     לוח מכירה / קניה הגדול בישראל!
# 26  pirsum                     לוח מכירה / קניה הגדול בישראל!
# 27  pirsum        רעננה, הרצליה, רמת השרון - פרסום חופשי ❤️🇮🇱
# 28  pirsum                  לוח מודעות - בת ים חולון ראשל"צ ♡
# 29  pirsum                                Ремонты, ремонты...
# 30  pirsum                                  תושבי תל אביב-יפו
# 31  pirsum                                     פרסום בחינם !!
# 32  pirsum                                        פרסום עסקים
# 33  pirsum         עושים שוק במרכז והשפלה ו -יד שניה ...קח ות
# 34  pirsum                             פורום נס ציונה והסביבה
# 35  pirsum                               לוח עסקים - רחובות !
# 36  pirsum                    Доска объявлений - весь Израиль
# 37  pirsum                                  Барахолка Израиль
# 38  pirsum                                  Барахолка Израиль
# 39  pirsum                     Русскоязычный бизнес в Израиле
# 40  pirsum                                    ProMaster.co.il
# 41  pirsum   https://www.facebook.com/groups/180537799074400/
# 42  pirsum                             Обмен услугами Израиль
# 43  pirsum                                  Барахолка Израиль
# 44  pirsum
# 45  pirsum
# 46  pirsum
# 47  pirsum                            עסקים ברמת גן - גבעתיים
# 48  pirsum                       ТЕЛЬ - АВИВ ✅Утро✅День✅Вечер
# 49  pirsum       פרסום עסקים ראשון,בת ים,חולון וכל אזור המרכז
# 50  pirsum               Тель-Авив » Доска объявлений Израиля
#
#                                description          ezor status_kvutza
# 0                                                  Рамла          None
# 1                                           Ришон лецион          None
# 2                                           Ришон лецион          None
# 3                                           Ришон лецион          None
# 4                                           Ришон лецион          None
# 5                                           Ришон лецион          None
# 6                                           Ришон лецион          None
# 7                                           Ришон лецион          None
# 8                                           Ришон лецион          None
# 9                                                Реховот          None
# 10                                               Израиль          None
# 11                                          Ришон лецион          None
# 12                                          Ришон лецион          None
# 13                                          Ришон лецион          None
# 14                                               Израиль          None
# 15                                               Израиль          None
# 16                                          Ришон лецион          None
# 17                                          Ришон лецион          None
# 18                                               Израиль          None
# 19                                               Израиль          None
# 20                                          Ришон лецион          None
# 21                                               Реховот          None
# 22                                          Ришон лецион          None
# 23                                             Тель авив          None
# 24                                          Ришон лецион          None
ru   https://www.facebook.com/groups/180537799074400/   aluf
# 42    346   ru   https://www.facebook.com/groups/180537799074400/   aluf
# 43    347   ru   https://www.facebook.com/groups/512082108878356/   aluf
# 44    348   ru           https://www.facebook.com/promaster.co.il   aluf
# 45    349   ru  https://www.facebook.com/groups/doskail/buy_se...   aluf
# 46    350   he  https://www.facebook.com/groups/1168933626609608/   aluf
# 47    351   he     https://www.facebook.com/groups/ramatgangroup/   aluf
# 48    352   he    https://www.facebook.com/groups/727595817771396   aluf
# 49    353   he   https://www.facebook.com/groups/343129716301937/   aluf
# 50    354   he      https://www.facebook.com/groups/TelAvivBoard/   aluf
# 51    355   ru  https://www.facebook.com/groups/1179991835346404/   aluf
#
#        url                                        group_title  \
# 0   pirsum                          פואבלו אספניול - נווה חוף
# 1   pirsum                            פורום תושבי שיכון המזרח
# 2   pirsum                           פורום ראשון למען התושבים
# 3   pirsum                        פורום שכונות כפר גנים א-ב-ג
# 4   pirsum                       פורום התושבים של ראשון לציון
# 5   pirsum               יהוד -מונסון שלנו לפרסום עסקים חופשי
# 6   pirsum               יהוד -מונסון שלנו לפרסום עסקים חופשי
# 7   pirsum  למכירה ברחובות Общедоступная группа  · Участни...
# 8   pirsum                        פורום בת ים המקורי מאיר בכר
# 9   pirsum                               פורום רחובות והסביבה
# 10  pirsum                           Доска объявлений Израиля
# 11  pirsum                                        ראשון לציון
# 12  pirsum                            פורום תושבי שיכון המזרח
# 13  pirsum                          פורום נס ציונה העיר והבית
# 14  pirsum                    woda.co.il - ОБЪЯВЛЕНИЯ ИЗРАИЛЯ
# 15  pirsum                                         פרסום חינם
# 16  pirsum      ראשל"צנט - עסקים ראשון לציון והסביבה באינטרנט
# 17  pirsum  פורום שכונת התקווה והסביבה פרסומים חינם מהאזור...
# 18  pirsum                                             פירסום
# 19  pirsum                פרסום חינם בכל תחום (לפרגן בלייקים)
# 20  pirsum                       פורום התושבים של ראשון לציון
# 21  pirsum                               לוח עסקים - רחובות !
# 22  pirsum      Ришон ле цион | Купи | Продай | Сними | Отдай
# 23  pirsum                                         מוכרים הכל
# 24  pirsum                  לוח מודעות - בת ים חולון ראשל"צ ♡
# 25  pirsum                     לוח מכירה / קניה הגדול בישראל!
# 26  pirsum                     לוח מכירה / קניה הגדול בישראל!
# 27  pirsum        רעננה, הרצליה, רמת השרון - פרסום חופשי ❤️🇮🇱
# 28  pirsum                  לוח מודעות - בת ים חולון ראשל"צ ♡
# 29  pirsum                                Ремонты, ремонты...
# 30  pirsum                                  תושבי תל אביב-יפו
# 31  pirsum                                     פרסום בחינם !!
# 32  pirsum                                        פרסום עסקים
# 33  pirsum         עושים שוק במרכז והשפלה ו -יד שניה ...קח ות
# 34  pirsum                             פורום נס ציונה והסביבה
# 35  pirsum                               לוח עסקים - רחובות !
# 36  pirsum                    Доска объявлений - весь Израиль
# 37  pirsum                                  Барахолка Израиль
# 38  pirsum                                  Барахолка Израиль
# 39  pirsum                     Русскоязычный бизнес в Израиле
# 40  pirsum                                    ProMaster.co.il
# 41  pirsum   https://www.facebook.com/groups/180537799074400/
# 42  pirsum                             Обмен услугами Израиль
# 43  pirsum                                  Барахолка Израиль
# 44  pirsum
# 45  pirsum
# 46  pirsum
# 19    322   he  https://www.facebook.com/groups/1988764218090482/   aluf
# 20    323   he   https://www.facebook.com/groups/832109660500543/   aluf
# 21    324   he   https://www.facebook.com/groups/839147156267947/   aluf
# 22    325   ru  https://www.facebook.com/groups/RishonLeZionIs...   aluf
# 23    326   ru   https://www.facebook.com/groups/293855971167565/   aluf
# 24    327   ru  https://www.facebook.com/groups/21241099912808...   aluf
# 25    328   ru  https://www.facebook.com/groups/1042412669171412/   aluf
# 26    329   ru  https://www.facebook.com/groups/10424126691714...   aluf
# 27    330   ru   https://www.facebook.com/groups/776769506064343/   aluf
# 28    331   ru   https://www.facebook.com/groups/212410999128080/   aluf
# 29    332   ru   https://www.facebook.com/groups/539932246694641/   aluf
# 30    333   ru  https://www.facebook.com/groups/2530024397218329/   aluf
# 31    334   ru   https://www.facebook.com/groups/298703436983060/   aluf
# 32    336   he  https://www.facebook.com/groups/11BusinessAdve...   aluf
# 33    337   he  https://www.facebook.com/groups/57562904931174...   aluf
# 34    338   he   https://www.facebook.com/groups/272843590109888/   aluf
# 35    339   he  https://www.facebook.com/groups/83914715626794...   aluf
# 36    340   ru           https://www.facebook.com/groups/doskail/   aluf
# 37    341   ru    https://www.facebook.com/groups/512082108878356   aluf
# 38    342   ru  https://www.facebook.com/groups/68122108197668...   aluf
# 39    343   ru  https://www.facebook.com/groups/56802212989859...   aluf
# 40    344   ru           https://www.facebook.com/promaster.co.il   aluf
# ...
#
#                                description          ezor status_kvutza
# 0                                                  Рамла          None
# 1                                           Ришон лецион          None
# 2                                           Ришон лецион          None
# 3                                           Ришон лецион          None
# 4                                           Ришон лецион          None
# 5                                           Ришон лецион          None
# 6                                           Ришон лецион          None
# 7                                           Ришон лецион          None
# 8                                           Ришон лецион          None
# 9                                                Реховот          None
# 10                                               Израиль          None
# 11                                          Ришон лецион          None
# 12                                          Ришон лецион          None
# 13                                          Ришон лецион          None
# 14                                               Израиль          None
# 15                                               Израиль          None
# 16                                          Ришон лецион          None
# 17                                          Ришон лецион          None
# 18                                               Израиль          None
# 19                                               Израиль          None
# 20                                          Ришон лецион          None
# 21                                               Реховот          None
# 22                                          Ришон лецион          None
# 23                                             Тель авив          None
# 24                                          Ришон лецион          None
# 25                                               Израиль          None
# 26                                               Израиль          None
# 27                                               Израиль          None
# 28                                          Ришон лецион          None
# 29                                               Израиль          None
# 30                                             Тель авив          None
# 31                                                 Центр          None
# 32                                               Израиль          None
# 33                                               Израиль          None
# 34                                              Несциона          None
# 35                                               Реховот          None
# 36                                               Израиль          None
# 37                                               Израиль          None
# 38                                               Израиль          None
# 39                                               Израиль          None
# 40  @promaster.co.il  · Услуги для бизнеса       Израиль          None
# 41                                               Израиль          None
# 42                                               Израиль          None
# 43                                               Израиль          None
# 44                                               Израиль          None
# 45                                               Израиль          None
# 46                                               Израиль          None
# 47                                                 Центр          None
# 48                                             Тель авив          None
# 49                                          Ришон лецион          None
# 50                                               Израиль          None
# 51                                          Ришон лецион          None
# 52                                          Ришон лецион          None
# 53                                          Ришон лецион          None
#     ROWID lang                                         sug_kvutza branch  \
# 48    352   he    https://www.facebook.com/groups/727595817771396   aluf
# 49    353   he   https://www.facebook.com/groups/343129716301937/   aluf
# 50    354   he      https://www.facebook.com/groups/TelAvivBoard/   aluf
# 51    355   ru  https://www.facebook.com/groups/1179991835346404/   aluf
# 52    356   he  https://www.facebook.com/groups/1017699601594766/   aluf
# 53    357   he  https://www.facebook.com/groups/1907227079318779/   aluf
# 54    358   he  https://www.facebook.com/groups/publish.rishon...   aluf
#
#        url                                        group_title  \
# 0   pirsum                          פואבלו אספניול - נווה חוף
# 1   pirsum                            פורום תושבי שיכון המזרח
# 2   pirsum                           פורום ראשון למען התושבים
# 3   pirsum                        פורום שכונות כפר גנים א-ב-ג
# 4   pirsum                       פורום התושבים של ראשון לציון
# 5   pirsum               יהוד -מונסון שלנו לפרסום עסקים חופשי
# 6   pirsum               יהוד -מונסון שלנו לפרסום עסקים חופשי
# 7   pirsum  למכירה ברחובות Общедоступная группа  · Участни...
# 8   pirsum                        פורום בת ים המקורי מאיר בכר
# 9   pirsum                               פורום רחובות והסביבה
# 10  pirsum                           Доска объявлений Израиля
# 11  pirsum                                        ראשון לציון
# 12  pirsum                            פורום תושבי שיכון המזרח
# 13  pirsum                          פורום נס ציונה העיר והבית
# 14  pirsum                    woda.co.il - ОБЪЯВЛЕНИЯ ИЗРАИЛЯ
# 15  pirsum                                         פרסום חינם
# 16  pirsum      ראשל"צנט - עסקים ראשון לציון והסביבה באינטרנט
# 17  pirsum  פורום שכונת התקווה והסביבה פרסומים חינם מהאזור...
# 18  pirsum                                             פירסום
# 19  pirsum                פרסום חינם בכל תחום (לפרגן בלייקים)
# 20  pirsum                       פורום התושבים של ראשון לציון
# 21  pirsum                               לוח עסקים - רחובות !
# 22  pirsum      Ришон ле цион | Купи | Продай | Сними | Отдай
# 23  pirsum                                         מוכרים הכל
# 24  pirsum                  לוח מודעות - בת ים חולון ראשל"צ ♡
# 25  pirsum                     לוח מכירה / קניה הגדול בישראל!
# 26  pirsum                     לוח מכירה / קניה הגדול בישראל!
# 27  pirsum        רעננה, הרצליה, רמת השרון - פרסום חופשי ❤️🇮🇱
# 28  pirsum                  לוח מודעות - בת ים חולון ראשל"צ ♡
# 29  pirsum                                Ремонты, ремонты...
# 30  pirsum                                  תושבי תל אביב-יפו
# 31  pirsum                                     פרסום בחינם !!
# 32  pirsum                                        פרסום עסקים
# 33  pirsum         עושים שוק במרכז והשפלה ו -יד שניה ...קח ות
# 34  pirsum                             פורום נס ציונה והסביבה
# 35  pirsum                               לוח עסקים - רחובות !
# 36  pirsum                    Доска объявлений - весь Израиль
# 37  pirsum                                  Барахолка Израиль
# 38  pirsum                                  Барахолка Израиль
# 39  pirsum                     Русскоязычный бизнес в Израиле
# 40  pirsum                                    ProMaster.co.il
# 41  pirsum   https://www.facebook.com/groups/180537799074400/
# 42  pirsum                             Обмен услугами Израиль
# 43  pirsum                                  Барахолка Израиль
# 44  pirsum
# 45  pirsum
# 46  pirsum
# 47  pirsum                            עסקים ברמת גן - גבעתיים
# 48  pirsum                       ТЕЛЬ - АВИВ ✅Утро✅День✅Вечер
# 49  pirsum       פרסום עסקים ראשון,בת ים,חולון וכל אזור המרכז
# 50  pirsum               Тель-Авив » Доска объявлений Израиля
# 51  pirsum                                     Ришон и друзья
# 52  pirsum                          יבנה הירוקה - פורום חברים
# 53  pirsum                              Ришон ле цион реклама
# 54  pirsum                     פרסום עסקים בראשון לציון בחינם
#
#                                description          ezor status_kvutza
# 0                                                  Рамла          None
# 1                                           Ришон лецион          None
# 2                                           Ришон лецион          None
# 3                                           Ришон лецион          None
# 4                                           Ришон лецион          None
# 5                                           Ришон лецион          None
# 6                                           Ришон лецион          None
# 7                                           Ришон лецион          None
# 8                                           Ришон лецион          None
# 9                                                Реховот          None
# 10                                               Израиль          None
# 11                                          Ришон лецион          None
# 12                                          Ришон лецион          None
# 13                                          Ришон лецион          None
# 14                                               Израиль          None
# 15                                               Израиль          None
# 16                                          Ришон лецион          None
# 17                                          Ришон лецион          None
# 18                                               Израиль          None
# 19                                               Израиль          None
# 20                                          Ришон лецион          None
# 21                                               Реховот          None
# 22                                          Ришон лецион          None
# 23                                             Тель авив          None
# 24                                          Ришон лецион          None
# 25                                               Израиль          None
# 26                                               Израиль          None
# 27                                               Израиль          None
# 28                                          Ришон лецион          None
# 29                                               Израиль          None
# 30                                             Тель авив          None
# 31                                                 Центр          None
# 32                                               Израиль          None
# 33                                               Израиль          None
# 34                                              Несциона          None
# 35                                               Реховот          None
# 36                                               Израиль          None
# 37                                               Израиль          None
# 38                                               Израиль          None
# 39                                               Израиль          None
# 40  @promaster.co.il  · Услуги для бизнеса       Израиль          None
# 41                                               Израиль          None
# 42                                               Израиль          None
# 43                                               Израиль          None
# 44                                               Израиль          None
# 45                                               Израиль          None
# 46                                               Израиль          None
# 47                                                 Центр          None
# 48                                             Тель авив          None
# 49                                          Ришон лецион          None
# 50                                               Израиль          None
# 51                                          Ришон лецион          None
# 52                                          Ришон лецион          None
# 53                                          Ришон лецион          None
# 54                                          Ришон лецион          None

# %%
def find_facebook_url_by_ROWID(ROWID):
    query = str(f'select url from fbgroups where ROWID = {ROWID}')
    df = db.execute(query , do='select')
    print(df)
# https://www.facebook.com/groups/244827598986210    

ROWID = widgets.Text(
    value='',
    placeholder='',
    description='ROWID' ,
    disabled=False   
)
display(ROWID)

def on_button_find_ROWID_clicked(b): 
    find_facebook_url_by_ROWID(ROWID.value)
    ROWID.value = ''

button_find_ROWID = widgets.Button(description="Find")
button_find_ROWID.on_click(on_button_find_ROWID_clicked) # Назначаем этот обработчик на событие "on_click"
display(button_find_ROWID)



def find_facebook_url_by_url(url):
    query = str(f'select ROWID from fbgroups where url like "{url}"')
    df = db.execute(query , do='select')
    print(df)
# https://www.facebook.com/groups/244827598986210    

find_by_URL = widgets.Text(
    value='',
    placeholder='',
    description='URL' ,
    disabled=False   
)
display(find_by_URL)

def button_find_ROWID_by_url_clicked(b): 
    find_facebook_url_by_url(find_by_URL.value)
    find_by_URL.value = ''
    

button_find_ROWID_by_url = widgets.Button(description="Find by URL")
button_find_ROWID_by_url.on_click(button_find_ROWID_by_url_clicked) # Назначаем этот обработчик на событие "on_click"
display(button_find_ROWID_by_url)
# Out:
# Text(value='', description='ROWID', placeholder='')
# Button(description='Find', style=ButtonStyle())
# Text(value='', description='URL', placeholder='')
# Button(description='Find by URL', style=ButtonStyle())
